# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('online_store_customer_data.csv')

# %%
df.head(10)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
# 7         1/3/2019          151207    Male  37.0        Married  Connecticut
# 8         1/4/2019          151208    Male  75.0        Married      Florida
# 9         1/4/2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %%
df.dropna(subset=['Age'],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                   0
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             152
# Amount_spent        239
# dtype: int64

# %%
gk = df.groupby(['Age', 'Marital_status']).groups

# %%
gk
# Out:
# {(15.0, 'Married'): [33, 54, 62, 67, 135, 169, 203, 272, 482, 651, 659, 1023, 1208, 1262, 1369, 1587, 1678, 1719, 2018, 2128, 2145, 2251, 2280, 2363, 2380, 2432], (15.0, 'Single'): [96, 212, 227, 306, 362, 584, 614, 720, 1980, 2103, 2244, 2321, 2419], (16.0, 'Married'): [50, 108, 115, 140, 155, 241, 492, 572, 599, 737, 840, 1004, 1210, 1238, 1270, 1314, 1371, 1446, 1468, 1472, 1528, 1802, 1863, 1876, 1901, 2021, 2074, 2221, 2349], (16.0, 'Single'): [15, 42, 487, 666, 896, 1179, 1378, 1731, 1869, 1930, 2165, 2166, 2179, 2197, 2225, 2430, 2460], (17.0, 'Married'): [30, 192, 210, 336, 546, 555, 777, 1123, 1181, 1195, 1320, 1450, 1520, 1530, 1975, 2020, 2025, 2124, 2195, 2216, 2327], (17.0, 'Single'): [175, 185, 218, 462, 550, 891, 1351, 1444, 1561, 1783, 1853, 2086, 2230], (18.0, 'Married'): [311, 460, 712, 755, 761, 927, 996, 1034, 1036, 1137, 1375, 1409, 1485, 1492, 1566, 1641, 1730, 1778, 1827, 1830, 1842, 2053, 2073, 2399], (18.0, 'Single'): [3, 146, 232, 242, 352, 603, 610, 648, 91
# ...

# %%
gk = df.groupby(['Marital_status','Age'])
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)
gk.first()
# Out:
#                     Transaction_date  Transaction_ID  Gender     State_names  \
# Marital_status Age
# Married        15.0        1/14/2019          151233    Male        Missouri
#                16.0        1/22/2019          151250  Female        Maryland
#                17.0        1/12/2019          151230    Male           Maine
#                18.0        4/17/2019          151502    Male         Arizona
#                19.0         1/8/2019          151220  Female          Hawaii
#                20.0         3/6/2019          151365  Female         Georgia
#                21.0        1/17/2019          151240  Female        Kentucky
#                22.0         2/6/2019          151295  Female          Kansas
#                24.0         1/5/2019          151214    Male        Colorado
#                25.0        1/11/2019          151225    Male         Indiana
#                26.0        2/19/2019          151330    Male           Idaho
# ...

# %%
df['Age'].describe()
# Out:
# count    2470.000000
# mean       46.637652
# std        18.186277
# min        15.000000
# 25%        32.000000
# 50%        47.000000
# 75%        62.000000
# max        78.000000
# Name: Age, dtype: float64

# %%
df.groupby('Age').describe()
# Out:
#      Transaction_ID                                                            \
#               count           mean         std       min        25%       50%
# Age
# 15.0           39.0  152356.153846  915.435172  151233.0  151438.00  152226.0
# 16.0           46.0  152501.739130  784.734674  151215.0  151812.00  152580.5
# 17.0           34.0  152431.294118  760.239178  151230.0  151742.00  152541.5
# 18.0           45.0  152508.466667  702.722129  151203.0  151955.00  152616.0
# 19.0           33.0  152295.454545  634.453756  151200.0  151905.00  152384.0
# 20.0           34.0  152580.029412  709.562797  151365.0  152070.50  152597.0
# 21.0           40.0  152500.950000  637.148171  151231.0  152160.50  152536.5
# 22.0           36.0  152530.944444  662.064949  151295.0  152120.25  152455.0
# 24.0           47.0  152382.340426  772.086171  151214.0  151723.50  152293.0
# 25.0           41.0  152678.219512  788.050268  151225.0  152231.00  152788.0
# ...

# %%
df.describe(include='all')
# Out:
#        Transaction_date  Transaction_ID  Gender          Age Marital_status  \
# count              2470     2470.000000    2442  2470.000000           2470
# unique              808             NaN       2          NaN              2
# top           8/29/2020             NaN  Female          NaN        Married
# freq                 12             NaN    1326          NaN           1446
# mean                NaN   152441.496761     NaN    46.637652            NaN
# std                 NaN      724.877228     NaN    18.186277            NaN
# min                 NaN   151200.000000     NaN    15.000000            NaN
# 25%                 NaN   151813.250000     NaN    32.000000            NaN
# 50%                 NaN   152438.500000     NaN    47.000000            NaN
# 75%                 NaN   153065.750000     NaN    62.000000            NaN
# max                 NaN   153699.000000     NaN    78.000000            NaN
#
# ...

# %%
df.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
summary=df.groupby('Marital_status')['Age'].agg(['mean','median','min','max','std'])

# %%
summary
# Out:
#                      mean  median   min   max        std
# Marital_status
# Married         46.459889    47.0  15.0  78.0  18.268948
# Single          46.888672    46.5  15.0  78.0  18.074823

# %%
import seaborn as sns

# %%
sns.boxplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(data=df,x='Age',y='Marital_status')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Marital_status'>

# %%
sns.boxplot(data=df,x='Age',y='Employees_status')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Employees_status'>
